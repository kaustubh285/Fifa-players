# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("data.csv")

# %%
dataset
# Out:
#        Unnamed: 0      ID                  Name  Age  \
# 0               0  158023              L. Messi   31
# 1               1   20801     Cristiano Ronaldo   33
# 2               2  190871             Neymar Jr   26
# 3               3  193080                De Gea   27
# 4               4  192985          K. De Bruyne   27
# 5               5  183277             E. Hazard   27
# 6               6  177003             L. Modrić   32
# 7               7  176580             L. Suárez   31
# 8               8  155862          Sergio Ramos   32
# 9               9  200389              J. Oblak   25
# 10             10  188545        R. Lewandowski   29
# 11             11  182521              T. Kroos   28
# 12             12  182493              D. Godín   32
# 13             13  168542           David Silva   32
# 14             14  215914              N. Kanté   27
# 15             15  211110             P. Dybala   24
# 16             16  202126               H. Kane   24
# ...

# %%
dataset.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
fifa = dataset[['Age','Overall', 'Potential','International Reputation','Skill Moves', 'Work Rate', 'Body Type','Crossing','Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling','Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration','SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower','Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression','Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure','Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling','GKKicking', 'GKPositioning', 'GKReflexes']]
fifa
# Out:
#        Age  Overall  Potential  International Reputation  Skill Moves  \
# 0       31       94         94                       5.0          4.0
# 1       33       94         94                       5.0          5.0
# 2       26       92         93                       5.0          5.0
# 3       27       91         93                       4.0          1.0
# 4       27       91         92                       4.0          4.0
# 5       27       91         91                       4.0          4.0
# 6       32       91         91                       4.0          4.0
# 7       31       91         91                       5.0          3.0
# 8       32       91         91                       4.0          3.0
# 9       25       90         93                       3.0          1.0
# 10      29       90         90                       4.0          4.0
# 11      28       90         90                       4.0          3.0
# ...

# %%
fifa = fifa.rename(columns={'Body Type': 'Body_type','International Reputation':'International_reputation','Skill Moves':'Skill_moves', 'Work Rate':'Work_rate'})

# %%
fifa.columns
# Out:
# Index(['Age', 'Overall', 'Potential', 'International_reputation',
#        'Skill_moves', 'Work_rate', 'Body_type', 'Crossing', 'Finishing',
#        'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling', 'Curve',
#        'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
#        'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
#        'GKKicking', 'GKPositioning', 'GKReflexes'],
#       dtype='object')

# %%
fifa['Body_type'].unique()
# Out:
# array(['Messi', 'C. Ronaldo', 'Neymar', 'Lean', 'Normal', 'Courtois',
#        'Stocky', 'PLAYER_BODY_TYPE_25', 'Shaqiri', 'Akinfenwa', nan],
#       dtype=object)

# %%
fifa['Work_rate'].unique()
# Out:
# array(['Medium/ Medium', 'High/ Low', 'High/ Medium', 'High/ High',
#        'Medium/ High', 'Medium/ Low', 'Low/ High', 'Low/ Medium',
#        'Low/ Low', nan], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelencoder_X_1 = LabelEncoder()
fifa['Body_type'] = labelencoder_X_1.fit_transform(fifa['Body_type'].astype(str))

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelencoder_X_1 = LabelEncoder()
fifa['Work_rate'] = labelencoder_X_1.fit_transform(fifa['Work_rate'].astype(str))

# %%
fifa
# Out:
#        Age  Overall  Potential  International_reputation  Skill_moves  \
# 0       31       94         94                       5.0          4.0
# 1       33       94         94                       5.0          5.0
# 2       26       92         93                       5.0          5.0
# 3       27       91         93                       4.0          1.0
# 4       27       91         92                       4.0          4.0
# 5       27       91         91                       4.0          4.0
# 6       32       91         91                       4.0          4.0
# 7       31       91         91                       5.0          3.0
# 8       32       91         91                       4.0          3.0
# 9       25       90         93                       3.0          1.0
# 10      29       90         90                       4.0          4.0
# 11      28       90         90                       4.0          3.0
# ...

# %%
fifa.dropna()
# Out:
#        Age  Overall  Potential  International_reputation  Skill_moves  \
# 0       31       94         94                       5.0          4.0
# 1       33       94         94                       5.0          5.0
# 2       26       92         93                       5.0          5.0
# 3       27       91         93                       4.0          1.0
# 4       27       91         92                       4.0          4.0
# 5       27       91         91                       4.0          4.0
# 6       32       91         91                       4.0          4.0
# 7       31       91         91                       5.0          3.0
# 8       32       91         91                       4.0          3.0
# 9       25       90         93                       3.0          1.0
# 10      29       90         90                       4.0          4.0
# 11      28       90         90                       4.0          3.0
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test =train_test_split(fifa[['Age', 'Potential','International_reputation','Skill_moves', 'Work_rate', 'Body_type','Crossing','Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling','Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration','SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower','Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression','Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure','Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling','GKKicking', 'GKPositioning', 'GKReflexes']],fifa[['Overall']], test_size=0.2, random_state=0)

# %%
x_test
# Out:
#        Age  Potential  International_reputation  Skill_moves  Work_rate  \
# 15885   22         65                       1.0          2.0          8
# 13652   22         69                       1.0          3.0          7
# 13522   24         65                       1.0          3.0          6
# 7814    23         76                       1.0          3.0          8
# 15904   19         72                       1.0          2.0          6
# 10429   30         65                       1.0          2.0          8
# 16002   32         58                       1.0          2.0          4
# 9550    29         66                       1.0          4.0          1
# 11574   26         66                       1.0          2.0          7
# 8822    29         66                       1.0          2.0          6
# 10727   20         79                       1.0          2.0          8
# 10149   20         79                       1.0          2.0          8
# ...

# %%
fifa.fillna(0, inplace=True)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
model.predict(x_test)
# Out:
# array([[57.04952088],
#        [61.77051985],
#        [60.54996676],
#        ...,
#        [63.56478463],
#        [57.93259464],
#        [57.39732771]])

# %%
model.score(x_test,y_test)
# Out:
# 0.9207986293833613
